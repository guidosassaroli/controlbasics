# %%
# !pip install control
# Out:
# Collecting control
#   Downloading control-0.10.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from control) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from control) (1.11.4)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from control) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.6->control) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sassaroli\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.16.0)
# Downloading control-0.10.1-py3-none-any.whl (549 kB)
#    ---------------------------------------- 0.0/549.6 kB ? eta -:--:--
#    ----------------------------- --------- 409.6/549.6 kB 12.9 MB/s eta 0:00:01
#    --------------------------------------- 549.6/549.6 kB 11.5 MB/s eta 0:00:00
# Installing collected packages: control
# Successfully installed control-0.10.1
# [notice] A new release of pip is available: 24.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

# %% [markdown]
# ## Define the plantTrue)

# %%
# Define a simple second-order plant: G(s) = 1 / (s^2 + 2s + 1)
num = [1]
den = [1, 2, 1]
G = ctrl.TransferFunction(num, den)

# Plot Bode of the plant
mag, phase, omega = ctrl.bode(G, dB=True, plot=True)
# Out:
# C:\Users\sassaroli\AppData\Local\anaconda3\Lib\site-packages\control\freqplot.py:435: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(

# %%
# Define a lead compensator: D(s) = (s + 10) / (10s + 1)
D = ctrl.TransferFunction([1, 10], [10, 1])

# Open-loop transfer function
L = D * G

# Bode plot of open-loop L = D*G
mag, phase, omega = ctrl.bode(L, dB=True, plot = True)

# Gain and phase margins
gm, pm, wg, wp = ctrl.margin(L)
print(f"Gain Margin: {gm:.2f}, Phase Margin: {pm:.2f}°, Crossover Frequency: {wp:.2f} rad/s")
# Out:
# C:\Users\sassaroli\AppData\Local\anaconda3\Lib\site-packages\control\freqplot.py:435: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
# Gain Margin: 3.06, Phase Margin: 33.93°, Crossover Frequency: 0.68 rad/s

# %%
# Closed-loop system T = L / (1 + L)
T = ctrl.feedback(L)

# Step response
t = np.linspace(0, 100, 1000)
t, y = ctrl.step_response(T, t)

plt.figure()
plt.plot(t, y)
plt.title('Step Response of Closed-Loop System')
plt.xlabel('Time [s]')
plt.ylabel('Output')
plt.grid(True)
plt.show()
